# %% [markdown]
# ## PART 1

# %%
'''
1. .csv
2. excel
3. text
4. json
5. zipped

6. XML
7. Html
8. docx
9. .mp3 & .mp4 
10 Images
11 Hierarchical Data Format
'''
# Out:
# '\n1. .csv\n2. excel\n3. text\n4. json\n5. zipped\n\n6. XML\n7. Html\n8. docx\n9. .mp3 & .mp4 \n10 Images\n11 Hierarchical Data Format\n'

# %%
import pandas as pd

#No1 - .csv files

df_csv = pd.read_csv('SalaryData_train.csv')

#No 2 - excel file

df_exel = pd.read_excel('sample1.xlsx')

#No3 - .txt file

df_txt = pd.read_csv('Salary.txt')

#No4 - .json files

df_json = pd.read_json('worldbank.json',lines=True)

#No5 - zipped File
import zipfile

zf = zipfile.ZipFile('SalaryData_Train.zip')
df_zip = pd.read_csv(zf.open('SalaryData_Train.csv'))

# %%
import pandas as pd

df = pd.read_html('https://en.wikipedia.org/wiki/2017_Indian_Premier_League')

df0 = pd.read_html('https://en.wikipedia.org/wiki/2017_Indian_Premier_League')[0]

df1 = pd.read_html('https://en.wikipedia.org/wiki/2017_Indian_Premier_League')[1]

df2 = pd.read_html('https://en.wikipedia.org/wiki/2017_Indian_Premier_League')[2]

df3 = pd.read_html('https://en.wikipedia.org/wiki/2017_Indian_Premier_League')[3]

dfa = pd.read_html('https://en.wikipedia.org/wiki/2017_Indian_Premier_League')[-4]

dfb = pd.read_html('https://en.wikipedia.org/wiki/2017_Indian_Premier_League')[-3]

dfc = pd.read_html('https://en.wikipedia.org/wiki/2017_Indian_Premier_League')[-2]
# Out:
# "\ndf1 = pd.read_html('https://en.wikipedia.org/wiki/2017_Indian_Premier_League')[1]\n\ndf2 = pd.read_html('https://en.wikipedia.org/wiki/2017_Indian_Premier_League')[2]\n\ndf3 = pd.read_html('https://en.wikipedia.org/wiki/2017_Indian_Premier_League')[3]\n\ndfa = pd.read_html('https://en.wikipedia.org/wiki/2017_Indian_Premier_League')[-4]\n\ndfb = pd.read_html('https://en.wikipedia.org/wiki/2017_Indian_Premier_League')[-3]\n\ndfc = pd.read_html('https://en.wikipedia.org/wiki/2017_Indian_Premier_League')[-2]\n"

# %%
df
# Out:
# [                       0                                             1
#  0                  Dates                         5 April – 21 May 2017
#  1       Administrator(s)  Board of Control for Cricket in India (BCCI)
#  2         Cricket format                                      Twenty20
#  3   Tournament format(s)               Double round robin and playoffs
#  4                Host(s)                                         India
#  5              Champions                    Mumbai Indians (3rd title)
#  6             Runners-up                        Rising Pune Supergiant
#  7           Participants                                             8
#  8         Matches played                                            60
#  9             Attendance                  1,592,543 (26,542 per match)
#  10  Player of the series    Ben Stokes (RPS) (316 runs and 12 wickets)
#  11             Most runs                      David Warner (SRH) (641)
# ...

# %%
df0
# Out:
#                        0                                             1
# 0                  Dates                         5 April – 21 May 2017
# 1       Administrator(s)  Board of Control for Cricket in India (BCCI)
# 2         Cricket format                                      Twenty20
# 3   Tournament format(s)               Double round robin and playoffs
# 4                Host(s)                                         India
# 5              Champions                    Mumbai Indians (3rd title)
# 6             Runners-up                        Rising Pune Supergiant
# 7           Participants                                             8
# 8         Matches played                                            60
# 9             Attendance                  1,592,543 (26,542 per match)
# 10  Player of the series    Ben Stokes (RPS) (316 runs and 12 wickets)
# 11             Most runs                      David Warner (SRH) (641)
# ...

# %% [markdown]
# ## Part 2 - Map External Values to Pandas Column

# %%
import pandas as pd

df = pd.DataFrame()

# %%
df['ID'] = [1111,2222,3333,4444,5555]

df['Name'] = ['Venkat','Soumya','Jatin','Nitin','Dupesh']

df['City'] = ['Hyderabad','Kolkata','Chandigarh','Bangalore','Jaipur']

# %%
df
# Out:
#      ID    Name        City
# 0  1111  Venkat   Hyderabad
# 1  2222  Soumya     Kolkata
# 2  3333   Jatin  Chandigarh
# 3  4444   Nitin   Bangalore
# 4  5555  Dupesh      Jaipur

# %%
city_to_state = {'Hyderabad':'Andhra Pradesh',
                 'Chandigarh':'Punjab',
                 'Jaipur':'Rajasthan',
                 'Kolkata':'West Bengal',
                 'Bangalore':'Karnataka'}

df['State'] = df['City'].map(city_to_state)

# %%
df
# Out:
#      ID    Name        City           State
# 0  1111  Venkat   Hyderabad  Andhra Pradesh
# 1  2222  Soumya     Kolkata     West Bengal
# 2  3333   Jatin  Chandigarh          Punjab
# 3  4444   Nitin   Bangalore       Karnataka
# 4  5555  Dupesh      Jaipur       Rajasthan

# %%
city_to_Region = {'Hyderabad':'Southern India',
                  'Kolkata':'Eastern India',
                  'Chandigarh':'Nothern India',
                  'Jaipur':'Western Part',
                  'Bangalore':'Southern India'}

df['Region'] = df['City'].map(city_to_Region)

# %%
df
# Out:
#      ID    Name        City           State          Region
# 0  1111  Venkat   Hyderabad  Andhra Pradesh  Southern India
# 1  2222  Soumya     Kolkata     West Bengal   Eastern India
# 2  3333   Jatin  Chandigarh          Punjab   Nothern India
# 3  4444   Nitin   Bangalore       Karnataka  Southern India
# 4  5555  Dupesh      Jaipur       Rajasthan    Western Part
